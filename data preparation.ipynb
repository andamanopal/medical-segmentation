# %% [markdown]
# # Data Preparation
# ------

# %%
import os, shutil
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
os.listdir('stent_data/image/')
# Out:
# ['b008_2.tif',
#  'b010_1.tif',
#  'b012_2.tif',
#  'b019_1.tif',
#  'b022_1.tif',
#  'b023_1.tif',
#  'b052_1.tif',
#  'b057_1.tif',
#  'b062_2.tif',
#  'b074_1.tif',
#  'b077_1.tif',
#  'b079_1.tif']

# %%
del img

# %%
image_path = 'stent_data/image/b008_2.tif'

img = Image.open(image_path)

# %%
img.seek(10)
img
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=1024x1024 at 0x18C762E0DC0>
